# %% [markdown]
# # Demo Notebook - Hệ thống Dự đoán Lương Nhân viên
#
# Notebook này demo các chức năng chính của hệ thống QLNS

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# TODO: Add demo code
